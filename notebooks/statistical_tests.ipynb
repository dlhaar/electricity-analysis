# %% [markdown]
# # Statistical tests on the change in the yearly production and consumption
# - H-null: the difference in values are not statistically significant
# - H-alt: the difference in values are statistically significant
#
# ** these values are not random, so this doesn't fit conceptually with statistical test

# %%
import functions
import pandas as pd
import yaml

# %% [markdown]
# ## Importing data

# %%
config = functions.read_yaml("./../config.yaml")

# %%
data = pd.read_csv(config['data']['smard_clean'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          1080 non-null   object
#  1   date          1080 non-null   object
#  2   source        1080 non-null   object
#  3   quantity_gwh  1080 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 33.9+ KB

# %%
data.head(3)
# Out:
#          type        date   source  quantity_gwh
# 0  generation  2017-01-01  biomass    3538.84775
# 1  generation  2017-02-01  biomass    3309.60100
# 2  generation  2017-03-01  biomass    3570.50050

# %% [markdown]
# ### Changing date to datetime object

# %%
data.date = pd.to_datetime(data['date'])

# %% [markdown]
# ## Splitting dataset into consumption and production

# %%
prod = data[data['type']=='generation'].copy()

# %%
prod.type.unique()
# Out:
# array(['generation'], dtype=object)

# %%
prod.shape
# Out:
# (864, 4)

# %%
consump = data[data['type']=='consumption'].copy()

# %%
consump.type.unique()
# Out:
# array(['consumption'], dtype=object)

# %%
consump.shape
# Out:
# (216, 4)

# %% [markdown]
# ## Production
# In the production dataset, there are 12 different categories:
# - biomass
# - hydropower
# - wind offshore
# - wind onshore
# - photovoltaics
# - other renewable
# - nuclear
# - lignite
# - hard coal
# - fossil gas
# - hyro pumped storage
# - other conventional
#
# In this dataset there is data in the amount of electricity produced by these sources in gigawatt-hours (GWh) from 2017 to 2022. The goal is to see if the changes in the total amount produced from one year to the next is statistically significant.

# %%
prod.head()
# Out:
#          type       date   source  quantity_gwh
# 0  generation 2017-01-01  biomass    3538.84775
# 1  generation 2017-02-01  biomass    3309.60100
# 2  generation 2017-03-01  biomass    3570.50050
# 3  generation 2017-04-01  biomass    3422.00900
# 4  generation 2017-05-01  biomass    3433.31325

# %%
prod.source.unique()
# Out:
# array(['biomass', 'hydropower', 'wind_offshore', 'wind_onshore',
#        'photovoltaics', 'other_renewable', 'nuclear', 'lignite',
#        'hard_coal', 'fossil_gas', 'hydro_pumped_storage',
#        'other_conventional'], dtype=object)

# %%
prod.source.nunique()
# Out:
# 12

# %% [markdown]
# ### Grouping sources into larger groups

# %%
source_groups = {'wind_offshore': 'wind',
                 'wind_onshore': 'wind',
                 'lignite': 'combustibles',
                 'hard_coal': 'combustibles',
                 'fossil_gas': 'combustibles',
                 'other_conventional': 'combustibles'
                }

# %%
source_groups.keys()
# Out:
# dict_keys(['wind_offshore', 'wind_onshore', 'lignite', 'hard_coal', 'fossil_gas', 'other_conventional'])

# %%
prod['source_groups']=prod['source'].apply(lambda x: source_groups[x] if x in source_groups.keys() else x)

# %%
prod.source_groups.unique()
# Out:
# array(['biomass', 'hydropower', 'wind', 'photovoltaics',
#        'other_renewable', 'nuclear', 'combustibles',
#        'hydro_pumped_storage'], dtype=object)

# %% [markdown]
# ### Statistical test - looking at year over year changes by production source

# %%
from scipy.stats import ttest_ind

# %%
prod.head()
# Out:
#          type       date   source  quantity_gwh source_groups
# 0  generation 2017-01-01  biomass    3538.84775       biomass
# 1  generation 2017-02-01  biomass    3309.60100       biomass
# 2  generation 2017-03-01  biomass    3570.50050       biomass
# 3  generation 2017-04-01  biomass    3422.00900       biomass
# 4  generation 2017-05-01  biomass    3433.31325       biomass

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 864 entries, 0 to 863
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           864 non-null    object
#  1   date           864 non-null    datetime64[ns]
#  2   source         864 non-null    object
#  3   quantity_gwh   864 non-null    float64
#  4   source_groups  864 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 40.5+ KB

# %%
def year_source_testing(df):

    df_temp = df.copy()

    results_dict = {}

    #get number of years in the dataset
    years = (df_temp['date']
             .dt.year
             .unique()
             .tolist()
            )

    #get sources in the dataset
    sources = df_temp['source_groups'].unique().tolist()

    for source in sources:
        for i, year in enumerate(years):
            try:
                group1 = df_temp[(df_temp['source_groups'] == source) & (df_temp['date'].dt.year == years[i])]
                group2 = df_temp[(df_temp['source_groups'] == source) & (df_temp['date'].dt.year == years[i+1])]

            except:
                pass
            
            ttest_statistic, pvalue = ttest_ind(group1['quantity_gwh'],group2['quantity_gwh'])

            source_key = source+'_'+str(i)

            results_dict[source_key]=[group1['date'].dt.year.unique()[0], group2['date'].dt.year.unique()[0], source, pvalue, pvalue < 0.05]

    df_results = pd.DataFrame.from_dict(results_dict, orient='index', columns = ['year1', 'year2', 'source', 'pvalue', 'pvalue_less_than_0.05'])
    
    return df_results

# %%
prod_results = year_source_testing(prod)
prod_results
# Out:
#                         year1  year2                source        pvalue  \
# biomass_0                2017   2018               biomass  7.683522e-01
# biomass_1                2018   2019               biomass  7.474973e-01
# biomass_2                2019   2020               biomass  6.281097e-01
# biomass_3                2020   2021               biomass  7.597893e-02
# biomass_4                2021   2022               biomass  9.891887e-01
# biomass_5                2022   2022               biomass  1.000000e+00
# hydropower_0             2017   2018            hydropower  7.755413e-01
# hydropower_1             2018   2019            hydropower  6.002565e-01
# hydropower_2             2019   2020            hydropower  7.967080e-01
# hydropower_3             2020   2021            hydropower  3.968616e-01
# hydropower_4             2021   2022            hydropower  1.236625e-01
# hydropower_5             2022   2022            hydropower  1.000000e+00
# wind_0                   2017   2018                  wind  8.130077e-01
# wind_1                   2018   2019                  wind  5.404689e-01
# wind_2                   2019   2020                  wind  8.396240e-01
# wind_3                   2020   2021                  wind  5.281230e-01
# wind_4                   2021   2022                  wind  6.514098e-01
# wind_5                   2022   2022                  wind  1.000000e+00
# photovoltaics_0          2017   2018         photovoltaics  5.798447e-01
# photovoltaics_1          2018   2019         photovoltaics  9.465889e-01
# photovoltaics_2          2019   2020         photovoltaics  7.120055e-01
# photovoltaics_3          2020   2021         photovoltaics  9.441816e-01
# photovoltaics_4          2021   2022         photovoltaics  4.877346e-01
# photovoltaics_5          2022   2022         photovoltaics  1.000000e+00
# other_renewable_0        2017   2018       other_renewable  5.157189e-02
# other_renewable_1        2018   2019       other_renewable  5.413325e-01
# other_renewable_2        2019   2020       other_renewable  1.441111e-01
# other_renewable_3        2020   2021       other_renewable  5.462408e-01
# other_renewable_4        2021   2022       other_renewable  1.013400e-02
# other_renewable_5        2022   2022       other_renewable  1.000000e+00
# nuclear_0                2017   2018               nuclear  9.276073e-01
# nuclear_1                2018   2019               nuclear  8.168358e-01
# nuclear_2                2019   2020               nuclear  6.035455e-03
# nuclear_3                2020   2021               nuclear  4.527939e-02
# nuclear_4                2021   2022               nuclear  1.548787e-17
# nuclear_5                2022   2022               nuclear  1.000000e+00
# combustibles_0           2017   2018          combustibles  6.881071e-01
# combustibles_1           2018   2019          combustibles  2.483089e-01
# combustibles_2           2019   2020          combustibles  2.976356e-01
# combustibles_3           2020   2021          combustibles  3.337002e-01
# combustibles_4           2021   2022          combustibles  9.814123e-01
# combustibles_5           2022   2022          combustibles  1.000000e+00
# hydro_pumped_storage_0   2017   2018  hydro_pumped_storage  7.738350e-01
# hydro_pumped_storage_1   2018   2019  hydro_pumped_storage  8.227797e-01
# hydro_pumped_storage_2   2019   2020  hydro_pumped_storage  2.211450e-06
# hydro_pumped_storage_3   2020   2021  hydro_pumped_storage  5.115668e-07
# hydro_pumped_storage_4   2021   2022  hydro_pumped_storage  1.263703e-03
# hydro_pumped_storage_5   2022   2022  hydro_pumped_storage  1.000000e+00
#
#                         pvalue_less_than_0.05
# biomass_0                               False
# biomass_1                               False
# biomass_2                               False
# biomass_3                               False
# biomass_4                               False
# biomass_5                               False
# hydropower_0                            False
# hydropower_1                            False
# hydropower_2                            False
# hydropower_3                            False
# hydropower_4                            False
# hydropower_5                            False
# wind_0                                  False
# wind_1                                  False
# wind_2                                  False
# wind_3                                  False
# wind_4                                  False
# wind_5                                  False
# photovoltaics_0                         False
# photovoltaics_1                         False
# photovoltaics_2                         False
# photovoltaics_3                         False
# photovoltaics_4                         False
# photovoltaics_5                         False
# other_renewable_0                       False
# other_renewable_1                       False
# other_renewable_2                       False
# other_renewable_3                       False
# other_renewable_4                        True
# other_renewable_5                       False
# nuclear_0                               False
# nuclear_1                               False
# nuclear_2                                True
# nuclear_3                                True
# nuclear_4                                True
# nuclear_5                               False
# combustibles_0                          False
# combustibles_1                          False
# combustibles_2                          False
# combustibles_3                          False
# combustibles_4                          False
# combustibles_5                          False
# hydro_pumped_storage_0                  False
# hydro_pumped_storage_1                  False
# hydro_pumped_storage_2                   True
# hydro_pumped_storage_3                   True
# hydro_pumped_storage_4                   True
# hydro_pumped_storage_5                  False

# %%
prod_results[prod_results['pvalue_less_than_0.05'] == True]
# Out:
#                         year1  year2                source        pvalue  \
# other_renewable_4        2021   2022       other_renewable  1.013400e-02
# nuclear_2                2019   2020               nuclear  6.035455e-03
# nuclear_3                2020   2021               nuclear  4.527939e-02
# nuclear_4                2021   2022               nuclear  1.548787e-17
# hydro_pumped_storage_2   2019   2020  hydro_pumped_storage  2.211450e-06
# hydro_pumped_storage_3   2020   2021  hydro_pumped_storage  5.115668e-07
# hydro_pumped_storage_4   2021   2022  hydro_pumped_storage  1.263703e-03
#
#                         pvalue_less_than_0.05
# other_renewable_4                        True
# nuclear_2                                True
# nuclear_3                                True
# nuclear_4                                True
# hydro_pumped_storage_2                   True
# hydro_pumped_storage_3                   True
# hydro_pumped_storage_4                   True

# %% [markdown]
# ### Statistical test - looking at total production year over year

# %%
def year_testing(df):

    df_temp = df.copy()

    results_dict = {}

    #get number of years in the dataset
    years = (df_temp['date']
             .dt.year
             .unique()
             .tolist()
            )

    for i, year in enumerate(years):
        try:
            group1 = df_temp[(df_temp['date'].dt.year == years[i])]
            group2 = df_temp[(df_temp['date'].dt.year == years[i+1])]

        except:
            pass
        
        ttest_statistic, pvalue = ttest_ind(group1['quantity_gwh'],group2['quantity_gwh'])

        dict_key = i

        results_dict[dict_key]=[group1['date'].dt.year.unique()[0], group2['date'].dt.year.unique()[0], pvalue, pvalue < 0.05]

    df_results = pd.DataFrame.from_dict(results_dict, orient='index', columns = ['year1', 'year2', 'pvalue', 'pvalue_less_than_0.05'])
    
    return df_results

# %%
year_testing(prod)
# Out:
#    year1  year2    pvalue  pvalue_less_than_0.05
# 0   2017   2018  0.938258                  False
# 1   2018   2019  0.688641                  False
# 2   2019   2020  0.607914                  False
# 3   2020   2021  0.856140                  False
# 4   2021   2022  0.811763                  False
# 5   2022   2022  1.000000                  False
